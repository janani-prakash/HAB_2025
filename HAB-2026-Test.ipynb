# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_excel('C:\\\\Users\\\\Janan\\\\anaconda_projects\\\\DATALOG.xlsx')

cols = [
    'BMP Temperature (C°)',
    'Pressure (Pa)',
    'Altitude (ft)',
    'Ozone (PPB)',
    'Radiation (CPM)',
    'Radiation (uSv_h)'
]

selected_df = df[cols]

selected_df = selected_df.apply(pd.to_numeric, errors='coerce')

corr_matrix = selected_df.corr()

print("\nCorrelation Matrix:")
print(corr_matrix)
# Out:
# Correlation Matrix:
#                       BMP Temperature (C°)  Pressure (Pa)  Altitude (ft)  \
# BMP Temperature (C°)              1.000000       0.902186      -0.707675
# Pressure (Pa)                     0.902186       1.000000      -0.920574
# Altitude (ft)                    -0.707675      -0.920574       1.000000
# Ozone (PPB)                      -0.665228      -0.580434       0.382140
# Radiation (CPM)                  -0.865723      -0.919667       0.899206
# Radiation (uSv_h)                -0.865716      -0.919665       0.899212
#
#                       Ozone (PPB)  Radiation (CPM)  Radiation (uSv_h)
# BMP Temperature (C°)    -0.665228        -0.865723          -0.865716
# Pressure (Pa)           -0.580434        -0.919667          -0.919665
# Altitude (ft)            0.382140         0.899206           0.899212
# Ozone (PPB)              1.000000         0.475885           0.475866
# Radiation (CPM)          0.475885         1.000000           1.000000
# ...

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix,
    annot=True,        # Show correlation values
    fmt=".2f",         # Format to 2 decimal places
    cmap="coolwarm",   # Color map
    vmin=-1, vmax=1,   # Fix color scale
    linewidths=0.5,    # Grid lines
    cbar=True          # Show color bar
)

plt.title("Correlation Matrix Heatmap", fontsize=14)
plt.tight_layout()
plt.show()

# %%
x_col = "Radiation (uSv_h)"
y_col = "Altitude (ft)"
plt.figure(figsize=(8,5))
plt.plot(df[x_col], df[y_col], marker='o')
plt.xlabel(x_col)
plt.ylabel(y_col)
plt.title(f"{y_col} vs {x_col}")
plt.grid(True)
plt.show()

# %%
x_col = "Radiation (uSv_h)"
y_col = "Pressure (Pa)"
plt.figure(figsize=(8,5))
plt.plot(df[x_col], df[y_col], marker='o')
plt.xlabel(x_col)
plt.ylabel(y_col)
plt.title(f"{y_col} vs {x_col}")
plt.grid(True)
plt.show()

# %%
x_col = "BMP Temperature (C°)"
y_col = "Altitude (ft)"
plt.figure(figsize=(8,5))
plt.plot(df[x_col], df[y_col], marker='o')
plt.xlabel(x_col)
plt.ylabel(y_col)
plt.title(f"{y_col} vs {x_col}")
plt.grid(True)
plt.show()

# %%
x_col = "Ozone (PPB)"
y_col = "Radiation (uSv_h)"
plt.figure(figsize=(8,5))
plt.plot(df[x_col], df[y_col], marker='o')
plt.xlabel(x_col)
plt.ylabel(y_col)
plt.title(f"{y_col} vs {x_col}")
plt.grid(True)
plt.show()

# %%
x_col = "Ozone (PPB)"
y_col = "Altitude (ft)"
plt.figure(figsize=(8,5))
plt.plot(df[x_col], df[y_col], marker='o')
plt.xlabel(x_col)
plt.ylabel(y_col)
plt.title(f"{y_col} vs {x_col}")
plt.grid(True)
plt.show()
